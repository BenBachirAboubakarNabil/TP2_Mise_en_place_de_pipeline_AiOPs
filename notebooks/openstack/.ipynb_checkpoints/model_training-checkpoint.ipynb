# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, roc_auc_score, confusion_matrix, roc_curve, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline
import joblib
import sys
sys.path.append('/app/notebooks/hdfs')
from utils import *

# %% [markdown]
# ##### Chargement des donnees pretraitees

# %%
try:
    X = joblib.load(PROCESSED_DIR / 'X_preprocessed.pkl')
    y = joblib.load(PROCESSED_DIR / 'y_preprocessed.pkl')
except FileNotFoundError:
    print(" Fichiers de donnees pretraitees non trouves. Executer l'etape 2 d'abord.")
    sys.exit(1)

n_success = sum(y==0)
n_fail = sum(y==1)
ratio = n_success / n_fail
print(f"Shape de X: {X.shape}")
# Out:
# Shape de X: (575061, 9)

# %%
RANDOM_STATE = 42
N_SPLITS = 10

# %%
# Donnees tres desequilibrees donc important de faire le rebalancement durant l'entrainement uniquement
# Utilisation de SMOTE pour le sur-echantillonnage de la classe minoritaire

smote_undersample_pipeline = ImbPipeline([
    # Suréchantillonne la classe minoritaire (Fail) pour atteindre 50% du majoritaire
    ('smote', SMOTE(sampling_strategy=0.5, random_state=RANDOM_STATE)),
    # Sous-échantillonne la classe majoritaire (Success) pour atteindre 50% de la nouvelle minorité
    ('under', RandomUnderSampler(sampling_strategy=1.0, random_state=RANDOM_STATE))
])

# %%
#  Definition des classifieurs
# regressions logistiques
lr = LogisticRegression(max_iter=1000, random_state=RANDOM_STATE, solver='liblinear')

# random forest
rf = RandomForestClassifier(n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1)

models = {
    'Logistic Regression': {
        'estimator': LogisticRegression(max_iter=1000, random_state=42),
        'results': {'precision': [], 'recall': [], 'auc': [], 'f1': []}
    },
    'Random Forest': {
        'estimator': RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1),
        'results': {'precision': [], 'recall': [], 'auc': [], 'f1': []}
    }
}

# %%
# Configuration de la Cross-Validation Stratifiée
cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# %%
print("Entraînement en cours...\n")


# Boucle principale de la Validation Croisée
for fold, (train_idx, test_idx) in enumerate(cv.split(X, y), 1):
    
    # 1. Séparation des données pour le fold actuel
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]
    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]
    
    # 2. Rééquilibrage sur TRAIN SEULEMENT avec SMOTE
    X_train_balanced, y_train_balanced = smote_undersample_pipeline.fit_resample(X_train, y_train)

    print(f"\n--- Fold {fold:2d}/{N_SPLITS} ---")
    
    # 3. Entraînement et Évaluation des modèles
    for name, model_data in models.items():
        estimator = model_data['estimator']
        results = model_data['results']
        
        # Entraînement
        estimator.fit(X_train_balanced, y_train_balanced)
        
        # Prédiction sur l'ensemble de TEST (NON rééquilibré)
        y_pred = estimator.predict(X_test)
        y_proba = estimator.predict_proba(X_test)[:, 1]
        
        # Stockage des métriques
        results['precision'].append(precision_score(y_test, y_pred))
        results['recall'].append(recall_score(y_test, y_pred))
        results['auc'].append(roc_auc_score(y_test, y_proba))
        
        print(f"  {name}: AUC={results['auc'][-1]:.4f}, Precision={results['precision'][-1]:.4f}, Recall={results['recall'][-1]:.4f}")

print("\n Cross-Validation termine")
# Out:
# Entraînement en cours...
#
#
# --- Fold  1/10 ---
#   Logistic Regression: AUC=0.9608, Precision=0.8972, Recall=0.9228
#   Random Forest: AUC=0.9658, Precision=0.9539, Recall=0.9222
#
# --- Fold  2/10 ---
#   Logistic Regression: AUC=0.9618, Precision=0.8721, Recall=0.9156
#   Random Forest: AUC=0.9658, Precision=0.9871, Recall=0.9127
#
# --- Fold  3/10 ---
#   Logistic Regression: AUC=0.9621, Precision=0.8863, Recall=0.9174
#   Random Forest: AUC=0.9657, Precision=0.9859, Recall=0.9162
#
# --- Fold  4/10 ---
#   Logistic Regression: AUC=0.9571, Precision=0.8760, Recall=0.9103
#   Random Forest: AUC=0.9598, Precision=0.9896, Recall=0.9080
#
# --- Fold  5/10 ---
#   Logistic Regression: AUC=0.9594, Precision=0.8755, Recall=0.9103
#   Random Forest: AUC=0.9671, Precision=0.9858, Recall=0.9097
#
# --- Fold  6/10 ---
#   Logistic Regression: AUC=0.9580, Precision=0.8817, Recall=0.9115
#   Random Forest: AUC=0.9618, Precision=0.9400, Recall=0.9109
#
# --- Fold  7/10 ---
#   Logistic Regression: AUC=0.9621, Precision=0.8865, Recall=0.9228
#   Random Forest: AUC=0.9647, Precision=0.9879, Recall=0.9198
#
# --- Fold  8/10 ---
#   Logistic Regression: AUC=0.9604, Precision=0.8975, Recall=0.9204
#   Random Forest: AUC=0.9633, Precision=0.9949, Recall=0.9186
#
# --- Fold  9/10 ---
#   Logistic Regression: AUC=0.9631, Precision=0.8898, Recall=0.9258
#   Random Forest: AUC=0.9660, Precision=0.9541, Recall=0.9258
#
# --- Fold 10/10 ---
#   Logistic Regression: AUC=0.9590, Precision=0.8898, Recall=0.9109
#   Random Forest: AUC=0.9615, Precision=0.9563, Recall=0.9086
#
#  Cross-Validation termine

# %%
# Calcul des moyennes
summary_data = {}
for name, model_data in models.items():
    avg_metrics = {
        'Précision Moyenne': np.mean(model_data['results']['precision']),
        'Rappel Moyen': np.mean(model_data['results']['recall']),
        'AUC Moyenne': np.mean(model_data['results']['auc'])
    }
    summary_data[name] = avg_metrics

results_df = pd.DataFrame(summary_data).T
print("\n Résultats Moyens de la Cross-Validation:")
print(results_df)
# Out:
#  Résultats Moyens de la Cross-Validation:
#                      Précision Moyenne  Rappel Moyen  AUC Moyenne
# Logistic Regression           0.885246      0.916795     0.960386
# Random Forest                 0.973554      0.915251     0.964151

# %%
# Affichage du meilleur modèle basé sur l'AUC
best_model_name = results_df['AUC Moyenne'].idxmax()
best_auc = results_df['AUC Moyenne'].max()

print(f"\n Meilleur modele: {best_model_name} (AUC = {best_auc:.4f})")
# Out:
#  Meilleur modele: Random Forest (AUC = 0.9642)

# %% [markdown]
# #### Visualisation de la Performance

# %%
# %% Visualisation améliorée
fig, ax = plt.subplots(figsize=(10, 6))

models_names = list(models.keys())
x = np.arange(len(models_names))
width = 0.25

# Calculer moyennes et std
precision_means = [np.mean(models[m]['results']['precision']) for m in models_names]
precision_stds = [np.std(models[m]['results']['precision']) for m in models_names]

recall_means = [np.mean(models[m]['results']['recall']) for m in models_names]
recall_stds = [np.std(models[m]['results']['recall']) for m in models_names]

auc_means = [np.mean(models[m]['results']['auc']) for m in models_names]
auc_stds = [np.std(models[m]['results']['auc']) for m in models_names]

# Barres avec erreurs
ax.bar(x - width, precision_means, width, yerr=precision_stds, 
       label='Précision', alpha=0.8, capsize=5)
ax.bar(x, recall_means, width, yerr=recall_stds, 
       label='Rappel', alpha=0.8, capsize=5)
ax.bar(x + width, auc_means, width, yerr=auc_stds, 
       label='AUC', alpha=0.8, capsize=5)

ax.set_ylabel('Score', fontweight='bold')
ax.set_title('Performances moyennes (10-fold CV)', fontweight='bold', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(models_names)
ax.legend()
ax.set_ylim([0.8, 1.0])
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(MODELS_DIR / 'results_barplot.png', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

# Pour chaque modèle, calculer ROC sur un fold (exemple: dernier fold)
colors = ['blue', 'green']

for idx, (name, model_data) in enumerate(models.items()):
    # Réentraîner sur dernier fold pour avoir y_proba
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]
    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]
    
    X_train_bal, y_train_bal = smote_undersample_pipeline.fit_resample(X_train, y_train)
    
    model_data['estimator'].fit(X_train_bal, y_train_bal)
    y_proba = model_data['estimator'].predict_proba(X_test)[:, 1]
    
    # Calculer courbe ROC
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    auc_score = np.mean(model_data['results']['auc'])
    
    ax.plot(fpr, tpr, color=colors[idx], lw=2, 
            label=f'{name} (AUC = {auc_score:.3f})')

# Ligne diagonale (classifier aléatoire)
ax.plot([0, 1], [0, 1], 'k--', lw=2, label='Aléatoire (AUC = 0.5)')

ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('Taux Faux Positifs (FPR)', fontweight='bold')
ax.set_ylabel('Taux Vrais Positifs (TPR)', fontweight='bold')
ax.set_title('Courbe ROC - Comparaison des modèles', fontweight='bold', fontsize=14)
ax.legend(loc="lower right")
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Matrice de Confusion
from sklearn.metrics import confusion_matrix

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (name, model_data) in enumerate(models.items()):
    # Réentraîner sur dernier fold
    X_train_last = X.iloc[train_idx]
    X_test_last = X.iloc[test_idx]
    y_train_last = y.iloc[train_idx]
    y_test_last = y.iloc[test_idx]
    
    X_train_bal, y_train_bal = smote_undersample_pipeline.fit_resample(X_train_last, y_train_last)
    
    model_data['estimator'].fit(X_train_bal, y_train_bal)
    y_pred = model_data['estimator'].predict(X_test_last)
    
    # Matrice de confusion
    cm = confusion_matrix(y_test_last, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # Plot
    im = axes[idx].imshow(cm, cmap='Blues', aspect='auto', vmin=0, vmax=cm.max())
    
    # Ajouter valeurs
    for i in range(2):
        for j in range(2):
            count = cm[i, j]
            text_color = 'white' if count > cm.max()/2 else 'black'
            
            axes[idx].text(j, i, f'{count:,}',
                          ha='center', va='center',
                          color=text_color, fontsize=14, fontweight='bold')
    
    # Labels
    axes[idx].set_xticks([0, 1])
    axes[idx].set_yticks([0, 1])
    axes[idx].set_xticklabels(['Success', 'Fail'], fontsize=11)
    axes[idx].set_yticklabels(['Success', 'Fail'], fontsize=11)
    axes[idx].set_xlabel('Predicted', fontweight='bold', fontsize=12)
    axes[idx].set_ylabel('True', fontweight='bold', fontsize=12)
    axes[idx].set_title(name, fontweight='bold', fontsize=13)
    
    # Stats
    precision = tp/(tp+fp) if (tp+fp) > 0 else 0
    recall = tp/(tp+fn) if (tp+fn) > 0 else 0
    
    stats = (f'TN: {tn:,}  FP: {fp:,}\n'
             f'FN: {fn:,}  TP: {tp:,}')
    
    axes[idx].text(0.5, -0.15, stats, transform=axes[idx].transAxes,
                   fontsize=10, ha='center', family='monospace',
                   bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.9))

plt.suptitle('Matrices de Confusion', fontweight='bold', fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 if last_y_test is not None:
#       2
#       3     # 1. Configuration de la figure
#       4     fig, axes = plt.subplots(1, 2, figsize=(14, 6))
#       5     axes = axes.flatten()
#
# NameError: name 'last_y_test' is not defined

# %% [markdown]
# #### Sauvegarder le meilleur modèle

# %%
# Identification et sauvegarde du meilleur modèle entraîné sur l'ensemble des données
if best_model_name == 'Logistic Regression':
    final_model = LogisticRegression(max_iter=1000, random_state=RANDOM_STATE, solver='liblinear')
else:
    final_model = RandomForestClassifier(n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1)

# Réentraînement du modèle final sur toutes les données rééquilibrées (SMOTE)
print(f"\nRéentraînement du modèle final ({best_model_name}) sur toutes les données rééquilibrées...")
X_final_balanced, y_final_balanced = smote_undersample_pipeline.fit_resample(X, y)
final_model.fit(X_final_balanced, y_final_balanced)

model_filename = f'{best_model_name.lower().replace(" ", "_")}.pkl'
joblib.dump(final_model, MODELS_DIR / model_filename)
joblib.dump(results_df, MODELS_DIR / 'results.pkl')
# Out:
# Réentraînement du modèle final (Random Forest) sur toutes les données rééquilibrées...
# ['/data/hdfs/models/results.pkl']
